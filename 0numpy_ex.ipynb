# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.3'

# %% [markdown]
# # numpy 객체 생성

# %%
# 리스트 -> ndarray
a=[1,2,3,4,5]
arr = np.array(a)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
len(arr)
# Out:
# 5

# %%
# 튜플 -> ndarray
a=[1,2,3,4,5]
arr = np.array(a)
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.size
# Out:
# 5

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
a=['a',1,2,3,4,5]
arr = np.array(a)
arr
# Out:
# array(['a', '1', '2', '3', '4', '5'], dtype='<U21')

# %%
a=[1.0,2,3,4,5]
arr = np.array(a)
arr
# Out:
# array([1., 2., 3., 4., 5.])

# %% [markdown]
# # 2차원 데이터 만들기

# %%
a2d =[[1,2,3], [3,4,5], [7,8,9]]
a2d
# Out:
# [[1, 2, 3], [3, 4, 5], [7, 8, 9]]

# %%
a2d = np.array(a2d)
a2d
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [7, 8, 9]])

# %%
# 2차원이기 떄문에 행의 갯수
len(a2d)
# Out:
# 3

# %%
# array의 전체 요소의 갯수
a2d.size
# Out:
# 9

# %%
a2d.dtype
# Out:
# dtype('int64')

# %%
a2d.shape
# Out:
# (3, 3)

# %%
a2d
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [7, 8, 9]])

# %%
np.save
